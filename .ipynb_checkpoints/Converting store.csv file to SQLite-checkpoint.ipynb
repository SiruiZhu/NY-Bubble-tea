# %%
import pandas as pd
import sqlite3

# %%
store_df = pd.read_csv("good_storeaddress.csv")

# %%
conn = sqlite3.connect('stores_db')

# %%
store_df.to_sql('stores',conn)
# Out:
# /Users/siruizhu/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py:2127: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
pd.read_sql('SELECT * FROM stores',conn)
# Out:
#      index  Unnamed: 0                                            address  \
# 0        0           0                  253 W 51st St\nNew York, NY 10019
# 1        1           1                 83-25 Broadway\nElmhurst, NY 11373
# 2        2           2                 13 St Marks Pl\nNew York, NY 10003
# 3        3           3                   65 Bayard St\nNew York, NY 10013
# 4        4           4                   85B Allen St\nNew York, NY 10002
# 5        5           5                  118 Baxter St\nNew York, NY 10013
# 6        6           6                   1700 2nd Ave\nNew York, NY 10128
# 7        7           7       433 Broome St\nGround Fl\nNew York, NY 10013
# 8        8           8                   17 W 32nd St\nNew York, NY 10001
# 9        9           9                   134 Smith St\nBrooklyn, NY 11201
# 10      10          10                     28 Jane St\nNew York, NY 10014
# 11      11          11               114 Macdougal St\nNew York, NY 10012
# ...
